# %%
import pandas as pd
import scipy as sp
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import matplotlib
import math
matplotlib.rcParams['figure.figsize'] = [10,8]
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv("C:\\Users\\suraj\\Desktop\\Autonomous Navi\\sensor_data.csv")

# %%
data.head()
# Out:
#    Linear_Acceleration.x  Linear_Acceleration.y  Linear_Acceleration.z  \
# 0               0.864224               0.229731               1.661541
# 1               0.323839               0.236918               1.652619
# 2              -1.202685               0.232506               0.568786
# 3              -1.450808               0.331171              -0.429112
# 4              -0.395831               0.194027              -1.022462
#
#    Rotation_Vector.x  Rotation_Vector.y  Rotation_Vector.z    GPS.lat  \
# 0           0.012974           0.164249           0.890385  13.017355
# 1           0.015850           0.160558           0.890426  13.017355
# 2           0.015416           0.157596           0.889407  13.017355
# 3           0.012804           0.160722           0.888201  13.017355
# 4           0.013176           0.163260           0.887135  13.017355
#
#     GPS.long  GPS.alt
# 0  77.568168      857
# 1  77.568168      857
# 2  77.568168      857
# 3  77.568168      857
# ...

# %%
lat = np.array(data['GPS.lat'])*math.pi/180
log = np.array(data['GPS.long'])*math.pi/180
r = 6371000
x = r*np.cos(lat)*np.cos(log)
y = r*np.cos(lat)*np.sin(log)
z = r*np.sin(lat)
plt.plot(x, y, label = 'Ground Truth')
plt.legend()
plt.xlabel ('X-Axis')
plt.ylabel ('Y-Axis')
plt.title('Ground Truth Plot (Distance in meters)')
plt.show()
